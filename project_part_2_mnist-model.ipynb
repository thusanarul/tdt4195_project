# %% [markdown]
# # CIFAR-10

# %% [markdown]
# ### Import libraries

# %%
import keras
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers import Dense, Flatten, Dropout, Input
from keras.layers import Conv2D, MaxPooling2D
import numpy as np
from collections import Counter
import matplotlib.pyplot as plt
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from keras.preprocessing.image import ImageDataGenerator
from keras import initializers, regularizers
from keras.models import load_model, Model
# Out:
# Using TensorFlow backend.

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

# %% [markdown]
# ### Sanity check

# %%
for i in range(3):
    for j in range(3):
        idx = i*3 + j + 1
        plt.subplot(3,3,idx)
        plt.imshow(X_train[idx-1])

# %% [markdown]
# ### Basic Data Statistics

# %%
num_of_classes = np.unique(y_train).shape[0]
print("Number of training examples: ", X_train.shape[0])
print("Number of testing examples: ", X_test.shape[0])
print("Shape of input images: ", X_train.shape[1:])
print("Data type: ", X_train.dtype)
print("Number of classes: ", num_of_classes)
# Out:
# Number of training examples:  50000
# Number of testing examples:  10000
# Shape of input images:  (32, 32, 3)
# Data type:  uint8
# Number of classes:  10

# %% [markdown]
# ### Pixel wise standardization

# %%
pixel_mean = X_train.mean(axis=0)
pixel_std = X_train.std(axis=0) + 1e-10 #prevents division by zero-error
# piwel-wise normalization on the train and test set
X_train = (X_train - pixel_mean) / pixel_std
X_test = (X_test - pixel_mean) / pixel_std

# %% [markdown]
# ### To_categorical

# %%
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %% [markdown]
# ### Change data shape

# %%
X_train = X_train.astype(np.float32)
X_test = X_test.astype(np.float32)

# %% [markdown]
# ### Split data

# %%
seed = 7
np.random.seed(seed)

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=seed)

print("Training set shape: ", X_train.shape)
print("Validation set shape: ", X_val.shape)
print("Testing set shape: ", X_test.shape)
# Out:
# Training set shape:  (40000, 32, 32, 3)
# Validation set shape:  (10000, 32, 32, 3)
# Testing set shape:  (10000, 32, 32, 3)

# %% [markdown]
# #### Perform some data augmentation
# Gjør mer av dette etterpå kanskje

# %%
datagen = ImageDataGenerator(fill_mode='constant',
                             width_shift_range=0.2,
                            height_shift_range=0.2,
                             cval=0,
                            )

datagen.fit(X_train)
for X_batch, y_batch in datagen.flow(X_train, y_train, batch_size=9):
    for i in range(0, 9):
        plt.subplot(330 + 1 + i)
        plt.imshow(X_batch[i].reshape(32, 32,3))
    plt.show()
    break
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## Load Mnist Model

# %%
mnist_model = load_model('my_model.h5')
model = Sequential()
model.add(Flatten(input_shape=(32,32,3)))
model.add(Dense(128, activation="relu"))
model.add(Dense(10, activation="softmax"))

# %% [markdown]
# #### Compile model

# %%
adam = keras.optimizers.Adam(lr=0.0001, epsilon=1e-8)

model.compile(optimizer=adam,
             loss="categorical_crossentropy",
             metrics=['accuracy'],
             )


model.layers[2].set_weights(mnist_model.layers[2].get_weights())
print(mnist_model.layers[2].get_weights())

model.summary()
# Out:
# [array([[-0.16641776, -0.2702754 , -0.28274545, ..., -0.26664916,
#          0.24675612,  0.05113506],
#        [ 0.25749844, -0.18655798, -0.11284086, ..., -0.31700915,
#          0.22981259,  0.06238803],
#        [ 0.2803112 ,  0.07872794,  0.14512594, ..., -0.1039006 ,
#          0.27355283, -0.18534142],
#        ...,
#        [ 0.08083223, -0.22602999,  0.13224724, ...,  0.04029442,
#         -0.11945938,  0.16630524],
#        [-0.09126677,  0.00711793, -0.33787757, ..., -0.05594772,
#          0.14353886,  0.13380773],
#        [-0.21067019, -0.09799551, -0.04937935, ..., -0.06095538,
#         -0.31119633,  0.14561853]], dtype=float32), array([-0.00171656, -0.0332822 , -0.01233585, -0.0160028 ,  0.01266978,
#        -0.02649306, -0.03637408, -0.04885193,  0.11429232,  0.00238606],
#       dtype=float32)]
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 3072)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               393344
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 394,634
# Trainable params: 394,634
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Train the model on images with slight augmentation

# %%
model.fit_generator(datagen.flow(X_train, y_train, batch_size=64),
                   steps_per_epoch=len(X_train)/64,
                   epochs=20,
                   validation_data=(X_val, y_val),
                   verbose=1)
# Out:
# Epoch 1/20
# 625/625 [==============================] - 19s 30ms/step - loss: 2.1172 - acc: 0.2753 - val_loss: 1.9620 - val_acc: 0.3425
# Epoch 2/20
# 625/625 [==============================] - 18s 28ms/step - loss: 1.9210 - acc: 0.3292 - val_loss: 1.8941 - val_acc: 0.3676
# Epoch 3/20
# 625/625 [==============================] - 17s 26ms/step - loss: 1.8571 - acc: 0.3493 - val_loss: 1.8437 - val_acc: 0.3790
# Epoch 4/20
# 625/625 [==============================] - 17s 28ms/step - loss: 1.8240 - acc: 0.3584 - val_loss: 1.8295 - val_acc: 0.3863
# Epoch 5/20
# 625/625 [==============================] - 19s 30ms/step - loss: 1.8008 - acc: 0.3679 - val_loss: 1.8024 - val_acc: 0.3968
# Epoch 6/20
# 625/625 [==============================] - 19s 30ms/step - loss: 1.7670 - acc: 0.3799 - val_loss: 1.7756 - val_acc: 0.3976
# Epoch 7/20
# 625/625 [==============================] - 18s 30ms/step - loss: 1.7499 - acc: 0.3861 - val_loss: 1.7815 - val_acc: 0.4092
# Epoch 8/20
# 625/625 [==============================] - 20s 32ms/step - loss: 1.7352 - acc: 0.3936 - val_loss: 1.7447 - val_acc: 0.4102
# Epoch 9/20
# 625/625 [==============================] - 18s 28ms/step - loss: 1.7195 - acc: 0.3955 - val_loss: 1.7171 - val_acc: 0.4195
# Epoch 10/20
# 625/625 [==============================] - 18s 28ms/step - loss: 1.7101 - acc: 0.3997 - val_loss: 1.7011 - val_acc: 0.4234
# Epoch 11/20
# 625/625 [==============================] - 18s 28ms/step - loss: 1.6986 - acc: 0.4002 - val_loss: 1.6868 - val_acc: 0.4271
# Epoch 12/20
# 625/625 [==============================] - 18s 28ms/step - loss: 1.6898 - acc: 0.4034 - val_loss: 1.7056 - val_acc: 0.4270
# Epoch 13/20
# 625/625 [==============================] - 18s 28ms/step - loss: 1.6772 - acc: 0.4118 - val_loss: 1.6868 - val_acc: 0.4263
# Epoch 14/20
# 625/625 [==============================] - 18s 28ms/step - loss: 1.6678 - acc: 0.4139 - val_loss: 1.6695 - val_acc: 0.4346
# Epoch 15/20
# 625/625 [==============================] - 18s 28ms/step - loss: 1.6608 - acc: 0.4162 - val_loss: 1.6887 - val_acc: 0.4342
# Epoch 16/20
# 625/625 [==============================] - 18s 29ms/step - loss: 1.6576 - acc: 0.4160 - val_loss: 1.6897 - val_acc: 0.4285
# Epoch 17/20
# 625/625 [==============================] - 18s 29ms/step - loss: 1.6505 - acc: 0.4178 - val_loss: 1.6389 - val_acc: 0.4427
# Epoch 18/20
# 625/625 [==============================] - 19s 30ms/step - loss: 1.6380 - acc: 0.4244 - val_loss: 1.6518 - val_acc: 0.4411
# Epoch 19/20
# 625/625 [==============================] - 19s 31ms/step - loss: 1.6297 - acc: 0.4243 - val_loss: 1.6489 - val_acc: 0.4382
# Epoch 20/20
# 625/625 [==============================] - 18s 29ms/step - loss: 1.6201 - acc: 0.4303 - val_loss: 1.6331 - val_acc: 0.4463

# %% [markdown]
# ### Visualize and analyse
#
# fit_generator tracks both loss and accuracy on training and validation set

# %% [markdown]
# #### Loss

# %%
history = model.history.history
plt.figure(figsize=(12, 8))
plt.plot(history["val_loss"], label="Validation loss")
plt.plot(history["loss"], label="Training loss")
plt.legend()

# %% [markdown]
# #### Accuracy

# %%
plt.figure(figsize=(12, 8))
plt.plot(history["val_acc"], label="Validation accuracy")
plt.plot(history["acc"], label="Training accuracy")

plt.legend()

# %% [markdown]
# ### Evaluation on test set

# %%
test_loss, test_acc = model.evaluate(X_test, y_test)
print("Test loss: ", test_loss)
print("Test acc: ", test_acc)
# Out:
# 10000/10000 [==============================] - 1s 58us/step
# Test loss:  1.6233047508239746
# Test acc:  0.4508

# %% [markdown]
# #### Compare to previous plot

# %%
history = model.history.history
plt.figure(figsize=(12, 8))
plt.plot(history["val_loss"], label="Validation loss")
plt.plot(history["loss"], label="Training loss")
plt.plot([19], [test_loss], 'o', label="Final test loss")
plt.legend()
