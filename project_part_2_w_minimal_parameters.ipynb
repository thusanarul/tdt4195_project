# %% [markdown]
# # CIFAR-10

# %% [markdown]
# ### Import libraries

# %%
import keras
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers import Dense, Flatten, Dropout
from keras.layers import Conv2D, MaxPooling2D
import numpy as np
from collections import Counter
import matplotlib.pyplot as plt
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from keras.preprocessing.image import ImageDataGenerator
from keras import initializers, regularizers

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

# %% [markdown]
# ### Sanity check

# %%
for i in range(3):
    for j in range(3):
        idx = i*3 + j + 1
        plt.subplot(3,3,idx)
        plt.imshow(X_train[idx-1])

# %% [markdown]
# ### Basic Data Statistics

# %%
num_of_classes = np.unique(y_train).shape[0]
print("Number of training examples: ", X_train.shape[0])
print("Number of testing examples: ", X_test.shape[0])
print("Shape of input images: ", X_train.shape[1:])
print("Data type: ", X_train.dtype)
print("Number of classes: ", num_of_classes)
# Out:
# Number of training examples:  50000
# Number of testing examples:  10000
# Shape of input images:  (32, 32, 3)
# Data type:  uint8
# Number of classes:  10

# %% [markdown]
# ### Pixel wise standardization

# %%
pixel_mean = X_train.mean(axis=0)
pixel_std = X_train.std(axis=0) + 1e-10 #prevents division by zero-error
# piwel-wise normalization on the train and test set
X_train = (X_train - pixel_mean) / pixel_std
X_test = (X_test - pixel_mean) / pixel_std

# %% [markdown]
# ### To_categorical

# %%
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %% [markdown]
# ### Change data shape

# %%
X_train = X_train.astype(np.float32)
X_test = X_test.astype(np.float32)

# %% [markdown]
# ### Split data

# %%
seed = 7
np.random.seed(seed)

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=seed)

print("Training set shape: ", X_train.shape)
print("Validation set shape: ", X_val.shape)
print("Testing set shape: ", X_test.shape)
# Out:
# Training set shape:  (40000, 32, 32, 3)
# Validation set shape:  (10000, 32, 32, 3)
# Testing set shape:  (10000, 32, 32, 3)

# %% [markdown]
# #### Perform some data augmentation
# Gjør mer av dette etterpå kanskje

# %%
datagen = ImageDataGenerator(fill_mode='constant',
                             width_shift_range=0.2,
                            height_shift_range=0.2,
                             cval=0,
                            )

datagen.fit(X_train)
for X_batch, y_batch in datagen.flow(X_train, y_train, batch_size=9):
    for i in range(0, 9):
        plt.subplot(330 + 1 + i)
        plt.imshow(X_batch[i].reshape(32, 32,3))
    plt.show()
    break
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## Build Model

# %%
model = Sequential()
model.add(Conv2D(32, (5,5), activation='relu', input_shape=(32,32,3)))
model.add(MaxPooling2D((2, 2), strides=(2, 2)))
model.add(Conv2D(64, (5,5), activation='relu'))
model.add(MaxPooling2D((2, 2), strides=(2, 2)))
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(10, activation='softmax'))

# %% [markdown]
# #### Compile model

# %%
adam = keras.optimizers.Adam(lr=0.00028, epsilon=1e-8)

model.compile(optimizer=adam,
             loss="categorical_crossentropy",
             metrics=['accuracy'],
             )

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 28, 28, 32)        2432
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 10, 10, 64)        51264
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 1600)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                102464
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                650
# =================================================================
# Total params: 156,810
# Trainable params: 156,810
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### Train the model on images with slight augmentation

# %%
model.fit_generator(datagen.flow(X_train, y_train, batch_size=64),
                   steps_per_epoch=len(X_train)/64,
                   epochs=20,
                   validation_data=(X_val, y_val),
                   verbose=1)
# Out:
# Epoch 1/20
# 625/625 [==============================] - 77s 122ms/step - loss: 1.0507 - acc: 0.6291 - val_loss: 0.9143 - val_acc: 0.6786
# Epoch 2/20
# 625/625 [==============================] - 74s 119ms/step - loss: 1.0366 - acc: 0.6345 - val_loss: 0.9128 - val_acc: 0.6833
# Epoch 3/20
# 625/625 [==============================] - 74s 119ms/step - loss: 1.0281 - acc: 0.6364 - val_loss: 0.9254 - val_acc: 0.6788
# Epoch 4/20
# 625/625 [==============================] - 78s 125ms/step - loss: 1.0213 - acc: 0.6371 - val_loss: 0.8689 - val_acc: 0.6990
# Epoch 5/20
# 625/625 [==============================] - 100s 160ms/step - loss: 1.0098 - acc: 0.6427 - val_loss: 0.8604 - val_acc: 0.7011
# Epoch 6/20
# 625/625 [==============================] - 145s 231ms/step - loss: 1.0005 - acc: 0.6452 - val_loss: 0.8816 - val_acc: 0.6959
# Epoch 7/20
# 625/625 [==============================] - 157s 252ms/step - loss: 0.9979 - acc: 0.6468 - val_loss: 0.8913 - val_acc: 0.6885
# Epoch 8/20
# 625/625 [==============================] - 96s 154ms/step - loss: 0.9904 - acc: 0.6484 - val_loss: 0.9093 - val_acc: 0.6893
# Epoch 9/20
# 625/625 [==============================] - 91s 146ms/step - loss: 0.9760 - acc: 0.6547 - val_loss: 0.8664 - val_acc: 0.6981
# Epoch 10/20
# 625/625 [==============================] - 138s 221ms/step - loss: 0.9717 - acc: 0.6561 - val_loss: 0.8906 - val_acc: 0.6939
# Epoch 11/20
# 625/625 [==============================] - 140s 224ms/step - loss: 0.9683 - acc: 0.6612 - val_loss: 0.8975 - val_acc: 0.6839
# Epoch 12/20
# 625/625 [==============================] - 106s 169ms/step - loss: 0.9697 - acc: 0.6602 - val_loss: 0.8727 - val_acc: 0.6972
# Epoch 13/20
# 625/625 [==============================] - 76s 122ms/step - loss: 0.9520 - acc: 0.6645 - val_loss: 0.8316 - val_acc: 0.7137
# Epoch 14/20
# 625/625 [==============================] - 74s 119ms/step - loss: 0.9474 - acc: 0.6673 - val_loss: 0.8725 - val_acc: 0.7006
# Epoch 15/20
# 625/625 [==============================] - 84s 134ms/step - loss: 0.9457 - acc: 0.6665 - val_loss: 0.8290 - val_acc: 0.7156
# Epoch 16/20
# 625/625 [==============================] - 81s 130ms/step - loss: 0.9339 - acc: 0.6712 - val_loss: 0.8327 - val_acc: 0.7155
# Epoch 17/20
# 625/625 [==============================] - 82s 132ms/step - loss: 0.9334 - acc: 0.6708 - val_loss: 0.8455 - val_acc: 0.7091
# Epoch 18/20
# 625/625 [==============================] - 82s 131ms/step - loss: 0.9358 - acc: 0.6696 - val_loss: 0.8465 - val_acc: 0.7060
# Epoch 19/20
# 625/625 [==============================] - 82s 130ms/step - loss: 0.9265 - acc: 0.6735 - val_loss: 0.8585 - val_acc: 0.7030
# Epoch 20/20
# 625/625 [==============================] - 84s 135ms/step - loss: 0.9188 - acc: 0.6752 - val_loss: 0.8180 - val_acc: 0.7189

# %% [markdown]
# ### Visualize and analyse
#
# fit_generator tracks both loss and accuracy on training and validation set

# %% [markdown]
# #### Loss

# %%
history = model.history.history
plt.figure(figsize=(12, 8))
plt.plot(history["val_loss"], label="Validation loss")
plt.plot(history["loss"], label="Training loss")
plt.legend()

# %% [markdown]
# #### Accuracy

# %%
plt.figure(figsize=(12, 8))
plt.plot(history["val_acc"], label="Validation accuracy")
plt.plot(history["acc"], label="Training accuracy")

plt.legend()

# %% [markdown]
# ### Evaluation on test set

# %%
test_loss, test_acc = model.evaluate(X_test, y_test)
print("Test loss: ", test_loss)
print("Test acc: ", test_acc)
# Out:
# 10000/10000 [==============================] - 6s 630us/step
# Test loss:  0.8154665535926818
# Test acc:  0.7147

# %% [markdown]
# #### Compare to previous plot

# %%
history = model.history.history
plt.figure(figsize=(12, 8))
plt.plot(history["val_loss"], label="Validation loss")
plt.plot(history["loss"], label="Training loss")
plt.plot([19], [test_loss], 'o', label="Final test loss")
plt.legend()
